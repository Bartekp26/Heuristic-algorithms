# %%
from abc_parallel import artificial_bee_colony_parallel
from objective_functions import sphere_function, heavy_monte_carlo

# %% [markdown]
# ## Wywołanie

# %%
best_solution, best_value, convergence = artificial_bee_colony_parallel(
    n_bees=30,
    dim=10,
    bounds=(-5, 5),
    max_iter=50,
    objective_func = heavy_monte_carlo 
)

best_value, best_solution[:5]
# Out:
# (np.float64(10.797439278924642),
#  array([ 0.01308369,  0.37867628,  0.04689362, -0.57641433,  0.01314167]))
